# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '5'
import torch
from diffusers import StableDiffusionXLImg2ImgPipeline
from diffusers.utils import load_image

pipe = StableDiffusionXLImg2ImgPipeline.from_pretrained(
    "/data1/zhengnanyan/huggingface/modelscope/AI-ModelScope/stable-diffusion-xl-base-1___0", torch_dtype=torch.float16, variant="fp16", use_safetensors=True
)
pipe = pipe.to("cuda")
# Out:
# /data1/zhengnanyan/miniconda3/envs/VLM310/lib/python3.10/site-packages/transformers/utils/hub.py:124: FutureWarning: Using `TRANSFORMERS_CACHE` is deprecated and will be removed in v5 of Transformers. Use `HF_HOME` instead.
#   warnings.warn(
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]

# %%
from PIL import Image
image = Image.open("/data1/zhengnanyan/code/VLM/data/images/菜头.png")
image = image.convert("RGB")

prompt = "Make this robot red"
images = pipe(prompt, image=image).images
images[0]
# Out:
#   0%|          | 0/15 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=480x440>

# %%
image
# Out:
# <PIL.Image.Image image mode=RGB size=2000x2000>
